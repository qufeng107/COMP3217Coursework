# %%
import numpy as np
import os
import pulp
import pandas as pd

from sklearn.linear_model import LinearRegression

import matplotlib.pyplot as plt
from matplotlib.ticker import MaxNLocator
from matplotlib.pyplot import MultipleLocator

# %%
hours = list(map(str, range(24))) 
prices_columns = list(map(str, range(24))) + ['label']
prices = pd.read_csv('./TestingResults.txt', names = prices_columns)
# prices = prices.loc[prices['label']==1]
prices.pop('label')

print(prices)
# Out:
#            0         1         2         3         4         5         6  \
# 0   4.512853  3.436581  3.682556  3.062718  3.456278  4.028039  3.530470
# 1   4.038201  3.874221  3.120743  3.261643  2.990717  3.789115  3.935849
# 2   4.343619  3.254605  3.130290  3.583647  3.021889  3.953010  4.379102
# 3   4.215916  3.310803  3.144808  2.826131  2.979042  3.264118  3.640009
# 4   4.607662  3.688971  3.804653  2.882434  3.247362  3.393615  3.720861
# ..       ...       ...       ...       ...       ...       ...       ...
# 95  4.697937  3.988722  3.145694  3.090585  3.587754  3.267644  3.668620
# 96  4.123134  3.682187  3.713447  3.454196  3.439953  3.668223  4.217498
# 97  3.931524  3.144742  3.432318  3.643773  3.025754  3.744014  3.707630
# 98  4.684524  4.123952  3.667197  2.961913  3.639619  3.801775  4.133400
# 99  4.274490  4.067073  3.684725  3.723503  3.651146  3.686348  3.981033
#
#            7         8         9  ...        14        15        16        17  \
# 0   4.292340  5.018994  4.783190  ...  5.857223  6.381602  6.115519  6.294756
# 1   4.391824  5.356575  5.274408  ...  5.822269  6.206444  5.631747  6.631983
# 2   4.432525  5.478115  4.914986  ...  5.284374  6.252251  5.771876  6.023015
# 3   4.332902  5.842453  4.560108  ...  5.437254  6.420271  6.014269  6.447240
# 4   3.600273  5.536350  4.653512  ...  5.402382  5.784929  6.340968  6.649603
# ..       ...       ...       ...  ...       ...       ...       ...       ...
# 95  4.405671  5.392661  4.741620  ...  5.124373  6.436753  6.267063  5.981062
# 96  3.974324  4.960387  4.619241  ...  5.503357  6.463162  5.729175  5.869843
# 97  3.936489  5.310619  5.328127  ...  5.336696  5.671983  5.739869  6.399843
# 98  3.976709  5.126293  4.925637  ...  5.621768  6.560280  5.389332  6.663719
# 99  4.127945  5.235410  5.245252  ...  5.788433  5.978219  5.872310  6.751915
#
#           18        19        20        21        22        23
# 0   6.513145  5.250190  5.913805  5.123827  5.629438  5.753545
# 1   6.593441  5.643768  5.930986  5.421773  5.150519  5.126661
# 2   6.340118  5.398613  5.176215  5.193332  5.543661  5.148262
# 3   6.788652  5.721373  5.923394  4.989043  5.797218  5.723375
# 4   6.720808  5.392021  5.130296  5.532805  6.028962  5.496418
# ..       ...       ...       ...       ...       ...       ...
# 95  6.548897  5.853540  5.778480  4.908238  5.818340  5.910066
# 96  6.490337  5.421610  5.673165  4.866852  6.054392  5.380646
# 97  6.630000  5.334260  5.275984  5.535441  5.988638  5.858969
# 98  6.637633  6.042505  5.855303  4.884481  5.689829  5.919360
# 99  6.681334  5.582147  5.275178  4.846575  5.517748  5.363707
#
# [100 rows x 24 columns]

# %%
usertask = pd.read_csv('./UserTask.csv')
usertask.pop('Maximum scheduled energy per hour')

print(usertask)
# Out:
#    User & Task ID  Ready Time  Deadline  Energy Demand
# 0     user1_task1          20        23              1
# 1     user1_task2          18        23              2
# 2     user1_task3          19        21              1
# 3     user1_task4          12        20              3
# 4     user1_task5           6        12              3
# 5     user1_task6          18        20              2
# 6     user1_task7           4        10              2
# 7     user1_task8          12        18              2
# 8     user1_task9           7        14              3
# 9    user1_task10           8        14              3
# 10    user2_task1          11        22              2
# 11    user2_task2           5        11              2
# 12    user2_task3           5        23              1
# 13    user2_task4           6        20              3
# 14    user2_task5          19        19              1
# 15    user2_task6          18        21              2
# 16    user2_task7           3        23              3
# 17    user2_task8          21        23              2
# 18    user2_task9          13        17              1
# 19   user2_task10           6        11              2
# 20    user3_task1          20        23              2
# 21    user3_task2          15        21              3
# 22    user3_task3          11        15              2
# 23    user3_task4           2        17              3
# 24    user3_task5          13        16              2
# 25    user3_task6          10        18              2
# 26    user3_task7          21        23              2
# 27    user3_task8          20        23              1
# 28    user3_task9           7        21              2
# 29   user3_task10           0         7              3
# 30    user4_task1           1         8              1
# 31    user4_task2          11        20              2
# 32    user4_task3          12        19              3
# 33    user4_task4          11        16              3
# 34    user4_task5          16        18              1
# 35    user4_task6          19        23              3
# 36    user4_task7          22        23              1
# 37    user4_task8          12        19              2
# 38    user4_task9           8        20              2
# 39   user4_task10           4        12              2
# 40    user5_task1           4        20              1
# 41    user5_task2          18        22              3
# 42    user5_task3           4        16              1
# 43    user5_task4           2        16              3
# 44    user5_task5          16        23              2
# 45    user5_task6           6        18              2
# 46    user5_task7           2         6              1
# 47    user5_task8          13        17              3
# 48    user5_task9          15        23              1
# 49   user5_task10          17        23              1

# %%
usertask.dtypes
# Out:
# User & Task ID    object
# Ready Time         int64
# Deadline           int64
# Energy Demand      int64
# dtype: object

# %%
# Construct our lp problems
# lp_user1 = pulp.LpProblem("My_LP_Problem", pulp.LpMinimize)
# ...
# lp_user5 = pulp.LpProblem("My_LP_Problem", pulp.LpMinimize)

for user_id in range(1,6):
    print("lp_user%s"%user_id)
    exec("lp_user%s=pulp.LpProblem('My_LP_Problem', pulp.LpMinimize)"%user_id)
# Out:
# lp_user1
# lp_user2
# lp_user3
# lp_user4
# lp_user5

# %%
# Construct our decision variables
# u1_t1_20 = pulp.LpVariable('u1_t1_20', lowBound=0, upBound=1, cat='Continuous')
# ...
# u5_t10_23 = pulp.LpVariable('u5_t10_23', lowBound=0, upBound=1, cat='Continuous')

task_by_hour = [[[]for j in range(24)] for i in range(5)]
task_by_id = [[[]for j in range(10)] for i in range(5)]

user_id = 1
task_id = 1

for task in usertask.itertuples():
    
    for hour in range(task[2],task[3]+1):
        exec("u%s_t%s_%s=pulp.LpVariable('u%s_t%s_%s', lowBound=0, upBound=1, cat='Continuous')"%(user_id,task_id,hour,user_id,task_id,hour))
        exec("task_by_hour[%s][%s].append(u%s_t%s_%s)"%(user_id-1,hour,user_id,task_id,hour))
        exec("task_by_id[%s][%s].append(u%s_t%s_%s)"%(user_id-1,task_id-1,user_id,task_id,hour))
        
    task_id += 1
    if task_id == 11:
        task_id = 1
        user_id += 1
        task

# %%
# define constrain


user_constrain = "0"
task_id = 1
user_id = 1

for task_energy in usertask['Energy Demand']:
    for task in task_by_id[user_id-1][task_id-1]:
        exec("user_constrain += '+ %s'"%task)
        
    exec("user_constrain += ' == %s'"%task_energy)
    exec("lp_user%s += %s"%(user_id,user_constrain))
    task_id += 1
    if task_id == 11:
        task_id = 1
        user_id += 1
    user_constrain = "0"

# %%
def plot_schedule(energy_usage,plt_name):
    
    energy_usage.append(0)
    
    # set coordinate label
    plt.xlabel('Time (H)')
    plt.ylabel('Total Power (KW)')
    
    # set x-coordinate scale label
    hour_list = list(map(int, range(25)))
    
    # set dpi and size of figure
    plt.figure(dpi = 300, figsize = (15,10))

    # set y-coordinate to int
    plt.gca().yaxis.set_major_locator(MaxNLocator(integer=True))
    
    # set y-coordinate interval to 1
    plt.gca().yaxis.set_major_locator(MultipleLocator(1))

    # draw bar chart
    plt.bar(range(25), energy_usage, width = 1,align = 'edge',linewidth = 1,edgecolor = 'black' , tick_label = hour_list)

    
    # save the bar chart
    plt.savefig('./scheduling_graph/energy_usage(guideline%s).jpg' % plt_name)   
    plt.close()

# %%
# Construct objective function and do calculation

tasklist = "0"
user_function = "0"
energy_usage = [0]*24

# print_log = open("./ScheduleResults.txt",'w')


for price in prices.itertuples():
    for user_id in range(1,6):
        for hour in range(0,24):
            for task in task_by_hour[user_id-1][hour]:
                exec("tasklist += '+ %s'"%task)
            
            exec("user_function += '+ (%s) * %s'"%(tasklist,price[hour+1]))
            tasklist = "0"
       
        exec("lp_user%s += %s"%(user_id,user_function))
        user_function = "0"
        
        # calculation for current user with current guideline price 
        exec("lp_user%s.solve()"%user_id)
        
        for hour in range(0,24):
            for task in task_by_hour[user_id-1][hour]:
                energy_usage[hour] += task.varValue
        
    plot_schedule(energy_usage,price[0])
    energy_usage = [0]*24
        # exec("print(pulp.LpStatus[lp_user%s.status])"%user_id)
        # exec("for variable in lp_user%s.variables(): print('{} = {}'.format(variable.name, variable.varValue))"%user_id)
        # exec("print(pulp.value(lp_user%s.objective))"%user_id)
        
        # exec("print('Current price guideline id: %s',file = print_log)"%price[0])
        # exec("for variable in lp_user%s.variables(): print('{} = {}'.format(variable.name, variable.varValue),file = print_log)"%user_id)
        # exec("print(pulp.value(lp_user%s.objective),file = print_log)"%user_id)
        # print('\n\n\n',file = print_log)


        

# print_log.close()
# Out:
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/reol/miniconda3/envs/tensorflow/lib/python3.9/site-packages/pulp/apis/../solverdir/cbc/osx/64/cbc /var/folders/zy/j2jkps316bzfk9v5fvqrr8rm0000gn/T/8bc1411dcca34181b27e400ec23025f8-pulp.mps timeMode elapsed branch printingOptions all solution /var/folders/zy/j2jkps316bzfk9v5fvqrr8rm0000gn/T/8bc1411dcca34181b27e400ec23025f8-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 15 COLUMNS
# At line 138 RHS
# At line 149 BOUNDS
# At line 211 ENDATA
# Problem MODEL has 10 rows, 61 columns and 61 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 8 (-2) rows, 54 (-7) columns and 54 (-7) elements
# 0  Obj 10.247654 Primal inf 19.999992 (8)
# 8  Obj 100.87087
# Optimal - objective value 100.87087
# After Postsolve, objective 100.87087, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective 100.8708686 - 8 iterations time 0.002, Presolve 0.00
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/reol/miniconda3/envs/tensorflow/lib/python3.9/site-packages/pulp/apis/../solverdir/cbc/osx/64/cbc /var/folders/zy/j2jkps316bzfk9v5fvqrr8rm0000gn/T/58244f82af764b2cae37ca217d045437-pulp.mps timeMode elapsed branch printingOptions all solution /var/folders/zy/j2jkps316bzfk9v5fvqrr8rm0000gn/T/58244f82af764b2cae37ca217d045437-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 15 COLUMNS
# At line 202 RHS
# At line 213 BOUNDS
# At line 307 ENDATA
# Problem MODEL has 10 rows, 93 columns and 93 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 7 (-3) rows, 68 (-25) columns and 68 (-25) elements
# 0  Obj 13.123296 Primal inf 15.999993 (7)
# 7  Obj 78.013012
# Optimal - objective value 78.013012
# After Postsolve, objective 78.013012, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective 78.01301151 - 7 iterations time 0.002, Presolve 0.00
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/reol/miniconda3/envs/tensorflow/lib/python3.9/site-packages/pulp/apis/../solverdir/cbc/osx/64/cbc /var/folders/zy/j2jkps316bzfk9v5fvqrr8rm0000gn/T/eaa77785c27e4d53a757c5bbf8f6def9-pulp.mps timeMode elapsed branch printingOptions all solution /var/folders/zy/j2jkps316bzfk9v5fvqrr8rm0000gn/T/eaa77785c27e4d53a757c5bbf8f6def9-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 15 COLUMNS
# At line 166 RHS
# At line 177 BOUNDS
# At line 253 ENDATA
# Problem MODEL has 10 rows, 75 columns and 75 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 9 (-1) rows, 71 (-4) columns and 71 (-4) elements
# 0  Obj 5.1238269 Primal inf 20.999991 (9)
# 9  Obj 96.965628
# Optimal - objective value 96.965628
# After Postsolve, objective 96.965628, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective 96.96562797 - 9 iterations time 0.002, Presolve 0.00
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/reol/miniconda3/envs/tensorflow/lib/python3.9/site-packages/pulp/apis/../solverdir/cbc/osx/64/cbc /var/folders/zy/j2jkps316bzfk9v5fvqrr8rm0000gn/T/8074ad4101fc4f61b734ad9b44a9e490-pulp.mps timeMode elapsed branch printingOptions all solution /var/folders/zy/j2jkps316bzfk9v5fvqrr8rm0000gn/T/8074ad4101fc4f61b734ad9b44a9e490-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 15 COLUMNS
# At line 160 RHS
# At line 171 BOUNDS
# At line 244 ENDATA
# Problem MODEL has 10 rows, 72 columns and 72 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 7 (-3) rows, 59 (-13) columns and 59 (-13) elements
# 0  Obj 14.807675 Primal inf 16.999993 (7)
# 7  Obj 92.59082
# Optimal - objective value 92.59082
# After Postsolve, objective 92.59082, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective 92.59081958 - 7 iterations time 0.002, Presolve 0.00
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/reol/miniconda3/envs/tensorflow/lib/python3.9/site-packages/pulp/apis/../solverdir/cbc/osx/64/cbc /var/folders/zy/j2jkps316bzfk9v5fvqrr8rm0000gn/T/d52d8ba9b3474070a520319350c7e390-pulp.mps timeMode elapsed branch printingOptions all solution /var/folders/zy/j2jkps316bzfk9v5fvqrr8rm0000gn/T/d52d8ba9b3474070a520319350c7e390-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 15 COLUMNS
# At line 210 RHS
# At line 221 BOUNDS
# At line 319 ENDATA
# Problem MODEL has 10 rows, 97 columns and 97 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 5 (-5) rows, 46 (-51) columns and 46 (-51) elements
# 0  Obj 20.222928 Primal inf 12.999995 (5)
# 5  Obj 80.117358
# Optimal - objective value 80.117358
# After Postsolve, objective 80.117358, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective 80.11735813 - 5 iterations time 0.002, Presolve 0.00
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
# /Users/reol/miniconda3/envs/tensorflow/lib/python3.9/site-packages/pulp/pulp.py:1704: UserWarning: Overwriting previously set objective.
#   warnings.warn("Overwriting previously set objective.")
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/reol/miniconda3/envs/tensorflow/lib/python3.9/site-packages/pulp/apis/../solverdir/cbc/osx/64/cbc /var/folders/zy/j2jkps316bzfk9v5fvqrr8rm0000gn/T/eeb8ac20e63a4733b8c89f902aa7471b-pulp.mps timeMode elapsed branch printingOptions all solution /var/folders/zy/j2jkps316bzfk9v5fvqrr8rm0000gn/T/eeb8ac20e63a4733b8c89f902aa7471b-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 15 COLUMNS
# At line 138 RHS
# At line 149 BOUNDS
# At line 211 ENDATA
# Problem MODEL has 10 rows, 61 columns and 61 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 8 (-2) rows, 54 (-7) columns and 54 (-7) elements
# 0  Obj 10.548434 Primal inf 19.999992 (8)
# 8  Obj 102.60338
# Optimal - objective value 102.60338
# After Postsolve, objective 102.60338, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective 102.6033821 - 8 iterations time 0.002, Presolve 0.00
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/reol/miniconda3/envs/tensorflow/lib/python3.9/site-packages/pulp/apis/../solverdir/cbc/osx/64/cbc /var/folders/zy/j2jkps316bzfk9v5fvqrr8rm0000gn/T/e8781271cb7745caa91ab0c0f9cb0231-pulp.mps timeMode elapsed branch printingOptions all solution /var/folders/zy/j2jkps316bzfk9v5fvqrr8rm0000gn/T/e8781271cb7745caa91ab0c0f9cb0231-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 15 COLUMNS
# At line 202 RHS
# At line 213 BOUNDS
# At line 307 ENDATA
# Problem MODEL has 10 rows, 93 columns and 93 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 7 (-3) rows, 68 (-25) columns and 68 (-25) elements
# 0  Obj 13.695971 Primal inf 15.999993 (7)
# 7  Obj 80.560041
# Optimal - objective value 80.560041
# After Postsolve, objective 80.560041, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective 80.56004082 - 7 iterations time 0.002, Presolve 0.00
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/reol/miniconda3/envs/tensorflow/lib/python3.9/site-packages/pulp/apis/../solverdir/cbc/osx/64/cbc /var/folders/zy/j2jkps316bzfk9v5fvqrr8rm0000gn/T/46dcb31542f3479fa101b54c56ee894c-pulp.mps timeMode elapsed branch printingOptions all solution /var/folders/zy/j2jkps316bzfk9v5fvqrr8rm0000gn/T/46dcb31542f3479fa101b54c56ee894c-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 15 COLUMNS
# At line 166 RHS
# At line 177 BOUNDS
# At line 253 ENDATA
# Problem MODEL has 10 rows, 75 columns and 75 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 9 (-1) rows, 71 (-4) columns and 71 (-4) elements
# 0  Obj 5.1266612 Primal inf 20.999991 (9)
# 9  Obj 95.278277
# Optimal - objective value 95.278277
# After Postsolve, objective 95.278277, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective 95.27827653 - 9 iterations time 0.002, Presolve 0.00
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/reol/miniconda3/envs/tensorflow/lib/python3.9/site-packages/pulp/apis/../solverdir/cbc/osx/64/cbc /var/folders/zy/j2jkps316bzfk9v5fvqrr8rm0000gn/T/c3d7dbd20f454fab90a3d9c62299af60-pulp.mps timeMode elapsed branch printingOptions all solution /var/folders/zy/j2jkps316bzfk9v5fvqrr8rm0000gn/T/c3d7dbd20f454fab90a3d9c62299af60-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 15 COLUMNS
# At line 160 RHS
# At line 171 BOUNDS
# At line 244 ENDATA
# Problem MODEL has 10 rows, 72 columns and 72 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 7 (-3) rows, 59 (-13) columns and 59 (-13) elements
# 0  Obj 13.749125 Primal inf 16.999993 (7)
# 7  Obj 91.552023
# Optimal - objective value 91.552023
# After Postsolve, objective 91.552023, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective 91.55202314 - 7 iterations time 0.002, Presolve 0.00
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/reol/miniconda3/envs/tensorflow/lib/python3.9/site-packages/pulp/apis/../solverdir/cbc/osx/64/cbc /var/folders/zy/j2jkps316bzfk9v5fvqrr8rm0000gn/T/c1bdecec2029402697218d2559161dd6-pulp.mps timeMode elapsed branch printingOptions all solution /var/folders/zy/j2jkps316bzfk9v5fvqrr8rm0000gn/T/c1bdecec2029402697218d2559161dd6-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 15 COLUMNS
# At line 210 RHS
# At line 221 BOUNDS
# At line 319 ENDATA
# Problem MODEL has 10 rows, 97 columns and 97 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 5 (-5) rows, 46 (-51) columns and 46 (-51) elements
# 0  Obj 19.225473 Primal inf 12.999995 (5)
# 5  Obj 78.567989
# Optimal - objective value 78.567989
# After Postsolve, objective 78.567989, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective 78.5679892 - 5 iterations time 0.002, Presolve 0.00
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/reol/miniconda3/envs/tensorflow/lib/python3.9/site-packages/pulp/apis/../solverdir/cbc/osx/64/cbc /var/folders/zy/j2jkps316bzfk9v5fvqrr8rm0000gn/T/94bbe9c32c744e08a64edbb086d7f81c-pulp.mps timeMode elapsed branch printingOptions all solution /var/folders/zy/j2jkps316bzfk9v5fvqrr8rm0000gn/T/94bbe9c32c744e08a64edbb086d7f81c-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 15 COLUMNS
# At line 138 RHS
# At line 149 BOUNDS
# At line 211 ENDATA
# Problem MODEL has 10 rows, 61 columns and 61 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 8 (-2) rows, 54 (-7) columns and 54 (-7) elements
# 0  Obj 10.324477 Primal inf 19.999992 (8)
# 8  Obj 101.64973
# Optimal - objective value 101.64973
# After Postsolve, objective 101.64973, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective 101.6497265 - 8 iterations time 0.002, Presolve 0.00
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/reol/miniconda3/envs/tensorflow/lib/python3.9/site-packages/pulp/apis/../solverdir/cbc/osx/64/cbc /var/folders/zy/j2jkps316bzfk9v5fvqrr8rm0000gn/T/09d74f8964b94b219ccb0b305e74aade-pulp.mps timeMode elapsed branch printingOptions all solution /var/folders/zy/j2jkps316bzfk9v5fvqrr8rm0000gn/T/09d74f8964b94b219ccb0b305e74aade-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 15 COLUMNS
# At line 202 RHS
# At line 213 BOUNDS
# At line 307 ENDATA
# Problem MODEL has 10 rows, 93 columns and 93 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 7 (-3) rows, 68 (-25) columns and 68 (-25) elements
# 0  Obj 13.698355 Primal inf 15.999993 (7)
# 7  Obj 81.066603
# Optimal - objective value 81.066603
# After Postsolve, objective 81.066603, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective 81.06660309 - 7 iterations time 0.002, Presolve 0.00
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/reol/miniconda3/envs/tensorflow/lib/python3.9/site-packages/pulp/apis/../solverdir/cbc/osx/64/cbc /var/folders/zy/j2jkps316bzfk9v5fvqrr8rm0000gn/T/5b080c1383dd4d0a99f5f6daf413a9e3-pulp.mps timeMode elapsed branch printingOptions all solution /var/folders/zy/j2jkps316bzfk9v5fvqrr8rm0000gn/T/5b080c1383dd4d0a99f5f6daf413a9e3-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 15 COLUMNS
# At line 166 RHS
# At line 177 BOUNDS
# At line 253 ENDATA
# Problem MODEL has 10 rows, 75 columns and 75 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 9 (-1) rows, 71 (-4) columns and 71 (-4) elements
# 0  Obj 5.1482616 Primal inf 20.999991 (9)
# 9  Obj 95.341226
# Optimal - objective value 95.341226
# After Postsolve, objective 95.341226, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective 95.34122568 - 9 iterations time 0.002, Presolve 0.00
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/reol/miniconda3/envs/tensorflow/lib/python3.9/site-packages/pulp/apis/../solverdir/cbc/osx/64/cbc /var/folders/zy/j2jkps316bzfk9v5fvqrr8rm0000gn/T/313c35a290e7403c901fabf1fbf796dc-pulp.mps timeMode elapsed branch printingOptions all solution /var/folders/zy/j2jkps316bzfk9v5fvqrr8rm0000gn/T/313c35a290e7403c901fabf1fbf796dc-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 15 COLUMNS
# At line 160 RHS
# At line 171 BOUNDS
# At line 244 ENDATA
# Problem MODEL has 10 rows, 72 columns and 72 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 7 (-3) rows, 59 (-13) columns and 59 (-13) elements
# 0  Obj 13.942026 Primal inf 16.999993 (7)
# 7  Obj 91.580147
# Optimal - objective value 91.580147
# After Postsolve, objective 91.580147, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective 91.58014735 - 7 iterations time 0.002, Presolve 0.00
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/reol/miniconda3/envs/tensorflow/lib/python3.9/site-packages/pulp/apis/../solverdir/cbc/osx/64/cbc /var/folders/zy/j2jkps316bzfk9v5fvqrr8rm0000gn/T/2627a5e49b944f67af03e8f284fd2f53-pulp.mps timeMode elapsed branch printingOptions all solution /var/folders/zy/j2jkps316bzfk9v5fvqrr8rm0000gn/T/2627a5e49b944f67af03e8f284fd2f53-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 15 COLUMNS
# At line 210 RHS
# At line 221 BOUNDS
# At line 319 ENDATA
# Problem MODEL has 10 rows, 97 columns and 97 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 5 (-5) rows, 46 (-51) columns and 46 (-51) elements
# 0  Obj 19.36219 Primal inf 12.999995 (5)
# 5  Obj 78.925746
# Optimal - objective value 78.925746
# After Postsolve, objective 78.925746, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective 78.9257459 - 5 iterations time 0.002, Presolve 0.00
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/reol/miniconda3/envs/tensorflow/lib/python3.9/site-packages/pulp/apis/../solverdir/cbc/osx/64/cbc /var/folders/zy/j2jkps316bzfk9v5fvqrr8rm0000gn/T/d5193541e7d849338afb8f2171fb5258-pulp.mps timeMode elapsed branch printingOptions all solution /var/folders/zy/j2jkps316bzfk9v5fvqrr8rm0000gn/T/d5193541e7d849338afb8f2171fb5258-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 15 COLUMNS
# At line 138 RHS
# At line 149 BOUNDS
# At line 211 ENDATA
# Problem MODEL has 10 rows, 61 columns and 61 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 8 (-2) rows, 54 (-7) columns and 54 (-7) elements
# 0  Obj 9.9780854 Primal inf 19.999992 (8)
# 8  Obj 101.8438
# Optimal - objective value 101.8438
# After Postsolve, objective 101.8438, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective 101.8437957 - 8 iterations time 0.002, Presolve 0.00
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/reol/miniconda3/envs/tensorflow/lib/python3.9/site-packages/pulp/apis/../solverdir/cbc/osx/64/cbc /var/folders/zy/j2jkps316bzfk9v5fvqrr8rm0000gn/T/1a51a0347b5c4bd287204d20849dbcac-pulp.mps timeMode elapsed branch printingOptions all solution /var/folders/zy/j2jkps316bzfk9v5fvqrr8rm0000gn/T/1a51a0347b5c4bd287204d20849dbcac-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 15 COLUMNS
# At line 202 RHS
# At line 213 BOUNDS
# At line 307 ENDATA
# Problem MODEL has 10 rows, 93 columns and 93 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 7 (-3) rows, 68 (-25) columns and 68 (-25) elements
# 0  Obj 13.608191 Primal inf 15.999993 (7)
# 7  Obj 78.617419
# Optimal - objective value 78.617419
# After Postsolve, objective 78.617419, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective 78.61741922 - 7 iterations time 0.002, Presolve 0.00
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/reol/miniconda3/envs/tensorflow/lib/python3.9/site-packages/pulp/apis/../solverdir/cbc/osx/64/cbc /var/folders/zy/j2jkps316bzfk9v5fvqrr8rm0000gn/T/c0141ee553da43aa91744440dc051149-pulp.mps timeMode elapsed branch printingOptions all solution /var/folders/zy/j2jkps316bzfk9v5fvqrr8rm0000gn/T/c0141ee553da43aa91744440dc051149-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 15 COLUMNS
# At line 166 RHS
# At line 177 BOUNDS
# At line 253 ENDATA
# Problem MODEL has 10 rows, 75 columns and 75 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 9 (-1) rows, 71 (-4) columns and 71 (-4) elements
# 0  Obj 4.9890427 Primal inf 20.999991 (9)
# 9  Obj 95.963264
# Optimal - objective value 95.963264
# After Postsolve, objective 95.963264, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective 95.96326401 - 9 iterations time 0.002, Presolve 0.00
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/reol/miniconda3/envs/tensorflow/lib/python3.9/site-packages/pulp/apis/../solverdir/cbc/osx/64/cbc /var/folders/zy/j2jkps316bzfk9v5fvqrr8rm0000gn/T/d70ec28e8974435bb68b097630ee5cf1-pulp.mps timeMode elapsed branch printingOptions all solution /var/folders/zy/j2jkps316bzfk9v5fvqrr8rm0000gn/T/d70ec28e8974435bb68b097630ee5cf1-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 15 COLUMNS
# At line 160 RHS
# At line 171 BOUNDS
# At line 244 ENDATA
# Problem MODEL has 10 rows, 72 columns and 72 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 7 (-3) rows, 59 (-13) columns and 59 (-13) elements
# 0  Obj 14.563775 Primal inf 16.999993 (7)
# 7  Obj 93.702128
# Optimal - objective value 93.702128
# After Postsolve, objective 93.702128, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective 93.70212844 - 7 iterations time 0.002, Presolve 0.00
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/reol/miniconda3/envs/tensorflow/lib/python3.9/site-packages/pulp/apis/../solverdir/cbc/osx/64/cbc /var/folders/zy/j2jkps316bzfk9v5fvqrr8rm0000gn/T/a638422a46c6481ab7b9efe0203629be-pulp.mps timeMode elapsed branch printingOptions all solution /var/folders/zy/j2jkps316bzfk9v5fvqrr8rm0000gn/T/a638422a46c6481ab7b9efe0203629be-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 15 COLUMNS
# At line 210 RHS
# At line 221 BOUNDS
# At line 319 ENDATA
# Problem MODEL has 10 rows, 97 columns and 97 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 5 (-5) rows, 46 (-51) columns and 46 (-51) elements
# 0  Obj 18.762301 Primal inf 12.999995 (5)
# 5  Obj 78.437016
# Optimal - objective value 78.437016
# After Postsolve, objective 78.437016, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective 78.43701578 - 5 iterations time 0.002, Presolve 0.00
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/reol/miniconda3/envs/tensorflow/lib/python3.9/site-packages/pulp/apis/../solverdir/cbc/osx/64/cbc /var/folders/zy/j2jkps316bzfk9v5fvqrr8rm0000gn/T/1d28cab56d234e3c942b95675ed3cd63-pulp.mps timeMode elapsed branch printingOptions all solution /var/folders/zy/j2jkps316bzfk9v5fvqrr8rm0000gn/T/1d28cab56d234e3c942b95675ed3cd63-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 15 COLUMNS
# At line 138 RHS
# At line 149 BOUNDS
# At line 211 ENDATA
# Problem MODEL has 10 rows, 61 columns and 61 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 8 (-2) rows, 54 (-7) columns and 54 (-7) elements
# 0  Obj 10.260593 Primal inf 19.999992 (8)
# 8  Obj 99.933056
# Optimal - objective value 99.933056
# After Postsolve, objective 99.933056, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective 99.93305627 - 8 iterations time 0.002, Presolve 0.00
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/reol/miniconda3/envs/tensorflow/lib/python3.9/site-packages/pulp/apis/../solverdir/cbc/osx/64/cbc /var/folders/zy/j2jkps316bzfk9v5fvqrr8rm0000gn/T/a1e0972eae7544a5b07a56fabbd68701-pulp.mps timeMode elapsed branch printingOptions all solution /var/folders/zy/j2jkps316bzfk9v5fvqrr8rm0000gn/T/a1e0972eae7544a5b07a56fabbd68701-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 15 COLUMNS
# At line 202 RHS
# At line 213 BOUNDS
# At line 307 ENDATA
# Problem MODEL has 10 rows, 93 columns and 93 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 7 (-3) rows, 68 (-25) columns and 68 (-25) elements
# 0  Obj 13.527673 Primal inf 15.999993 (7)
# 7  Obj 78.719226
# Optimal - objective value 78.719226
# After Postsolve, objective 78.719226, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective 78.71922586 - 7 iterations time 0.002, Presolve 0.00
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/reol/miniconda3/envs/tensorflow/lib/python3.9/site-packages/pulp/apis/../solverdir/cbc/osx/64/cbc /var/folders/zy/j2jkps316bzfk9v5fvqrr8rm0000gn/T/b02a7606837e4af2b2fccf67365d19e1-pulp.mps timeMode elapsed branch printingOptions all solution /var/folders/zy/j2jkps316bzfk9v5fvqrr8rm0000gn/T/b02a7606837e4af2b2fccf67365d19e1-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 15 COLUMNS
# At line 166 RHS
# At line 177 BOUNDS
# At line 253 ENDATA
# Problem MODEL has 10 rows, 75 columns and 75 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 9 (-1) rows, 71 (-4) columns and 71 (-4) elements
# 0  Obj 5.1302965 Primal inf 20.999991 (9)
# 9  Obj 96.724556
# Optimal - objective value 96.724556
# After Postsolve, objective 96.724556, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective 96.72455633 - 9 iterations time 0.002, Presolve 0.00
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/reol/miniconda3/envs/tensorflow/lib/python3.9/site-packages/pulp/apis/../solverdir/cbc/osx/64/cbc /var/folders/zy/j2jkps316bzfk9v5fvqrr8rm0000gn/T/7201e40d759d414980b0bb96e39c9409-pulp.mps timeMode elapsed branch printingOptions all solution /var/folders/zy/j2jkps316bzfk9v5fvqrr8rm0000gn/T/7201e40d759d414980b0bb96e39c9409-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 15 COLUMNS
# At line 160 RHS
# At line 171 BOUNDS
# At line 244 ENDATA
# Problem MODEL has 10 rows, 72 columns and 72 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 7 (-3) rows, 59 (-13) columns and 59 (-13) elements
# 0  Obj 14.719821 Primal inf 16.999993 (7)
# 7  Obj 94.197609
# Optimal - objective value 94.197609
# After Postsolve, objective 94.197609, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective 94.19760917 - 7 iterations time 0.002, Presolve 0.00
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/reol/miniconda3/envs/tensorflow/lib/python3.9/site-packages/pulp/apis/../solverdir/cbc/osx/64/cbc /var/folders/zy/j2jkps316bzfk9v5fvqrr8rm0000gn/T/408859a0b3304667ae61cca1d03e7d22-pulp.mps timeMode elapsed branch printingOptions all solution /var/folders/zy/j2jkps316bzfk9v5fvqrr8rm0000gn/T/408859a0b3304667ae61cca1d03e7d22-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 15 COLUMNS
# At line 210 RHS
# At line 221 BOUNDS
# At line 319 ENDATA
# Problem MODEL has 10 rows, 97 columns and 97 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 5 (-5) rows, 46 (-51) columns and 46 (-51) elements
# 0  Obj 19.637752 Primal inf 12.999995 (5)
# 5  Obj 78.989085
# Optimal - objective value 78.989085
# After Postsolve, objective 78.989085, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective 78.98908497 - 5 iterations time 0.002, Presolve 0.00
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/reol/miniconda3/envs/tensorflow/lib/python3.9/site-packages/pulp/apis/../solverdir/cbc/osx/64/cbc /var/folders/zy/j2jkps316bzfk9v5fvqrr8rm0000gn/T/d3de76063be84a43ae728b92e4d60984-pulp.mps timeMode elapsed branch printingOptions all solution /var/folders/zy/j2jkps316bzfk9v5fvqrr8rm0000gn/T/d3de76063be84a43ae728b92e4d60984-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 15 COLUMNS
# At line 138 RHS
# At line 149 BOUNDS
# At line 211 ENDATA
# Problem MODEL has 10 rows, 61 columns and 61 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 8 (-2) rows, 54 (-7) columns and 54 (-7) elements
# 0  Obj 10.296194 Primal inf 19.999992 (8)
# 8  Obj 100.97748
# Optimal - objective value 100.97748
# After Postsolve, objective 100.97748, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective 100.9774757 - 8 iterations time 0.002, Presolve 0.00
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/reol/miniconda3/envs/tensorflow/lib/python3.9/site-packages/pulp/apis/../solverdir/cbc/osx/64/cbc /var/folders/zy/j2jkps316bzfk9v5fvqrr8rm0000gn/T/6c82da66a3bb4b05bb1523be405c6f63-pulp.mps timeMode elapsed branch printingOptions all solution /var/folders/zy/j2jkps316bzfk9v5fvqrr8rm0000gn/T/6c82da66a3bb4b05bb1523be405c6f63-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 15 COLUMNS
# At line 202 RHS
# At line 213 BOUNDS
# At line 307 ENDATA
# Problem MODEL has 10 rows, 93 columns and 93 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 7 (-3) rows, 68 (-25) columns and 68 (-25) elements
# 0  Obj 13.183158 Primal inf 15.999993 (7)
# 7  Obj 79.072936
# Optimal - objective value 79.072936
# After Postsolve, objective 79.072936, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective 79.07293622 - 7 iterations time 0.002, Presolve 0.00
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/reol/miniconda3/envs/tensorflow/lib/python3.9/site-packages/pulp/apis/../solverdir/cbc/osx/64/cbc /var/folders/zy/j2jkps316bzfk9v5fvqrr8rm0000gn/T/05aabbd8d7ea4768a0951be3bb5e6211-pulp.mps timeMode elapsed branch printingOptions all solution /var/folders/zy/j2jkps316bzfk9v5fvqrr8rm0000gn/T/05aabbd8d7ea4768a0951be3bb5e6211-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 15 COLUMNS
# At line 166 RHS
# At line 177 BOUNDS
# At line 253 ENDATA
# Problem MODEL has 10 rows, 75 columns and 75 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 9 (-1) rows, 71 (-4) columns and 71 (-4) elements
# 0  Obj 5.19956 Primal inf 20.999991 (9)
# 9  Obj 96.495639
# Optimal - objective value 96.495639
# After Postsolve, objective 96.495639, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective 96.49563872 - 9 iterations time 0.002, Presolve 0.00
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/reol/miniconda3/envs/tensorflow/lib/python3.9/site-packages/pulp/apis/../solverdir/cbc/osx/64/cbc /var/folders/zy/j2jkps316bzfk9v5fvqrr8rm0000gn/T/7aeb466846ed416883bf2c98403b3d60-pulp.mps timeMode elapsed branch printingOptions all solution /var/folders/zy/j2jkps316bzfk9v5fvqrr8rm0000gn/T/7aeb466846ed416883bf2c98403b3d60-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 15 COLUMNS
# At line 160 RHS
# At line 171 BOUNDS
# At line 244 ENDATA
# Problem MODEL has 10 rows, 72 columns and 72 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 7 (-3) rows, 59 (-13) columns and 59 (-13) elements
# 0  Obj 14.266657 Primal inf 16.999993 (7)
# 7  Obj 93.167186
# Optimal - objective value 93.167186
# After Postsolve, objective 93.167186, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective 93.1671857 - 7 iterations time 0.002, Presolve 0.00
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/reol/miniconda3/envs/tensorflow/lib/python3.9/site-packages/pulp/apis/../solverdir/cbc/osx/64/cbc /var/folders/zy/j2jkps316bzfk9v5fvqrr8rm0000gn/T/2376f9a557be44f68f8974a11514dd86-pulp.mps timeMode elapsed branch printingOptions all solution /var/folders/zy/j2jkps316bzfk9v5fvqrr8rm0000gn/T/2376f9a557be44f68f8974a11514dd86-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 15 COLUMNS
# At line 210 RHS
# At line 221 BOUNDS
# At line 319 ENDATA
# Problem MODEL has 10 rows, 97 columns and 97 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 5 (-5) rows, 46 (-51) columns and 46 (-51) elements
# 0  Obj 19.560244 Primal inf 12.999995 (5)
# 5  Obj 78.851067
# Optimal - objective value 78.851067
# After Postsolve, objective 78.851067, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective 78.85106674 - 5 iterations time 0.002, Presolve 0.00
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/reol/miniconda3/envs/tensorflow/lib/python3.9/site-packages/pulp/apis/../solverdir/cbc/osx/64/cbc /var/folders/zy/j2jkps316bzfk9v5fvqrr8rm0000gn/T/d86f89f4ee3e43ba8ee81762e46c8d06-pulp.mps timeMode elapsed branch printingOptions all solution /var/folders/zy/j2jkps316bzfk9v5fvqrr8rm0000gn/T/d86f89f4ee3e43ba8ee81762e46c8d06-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 15 COLUMNS
# At line 138 RHS
# At line 149 BOUNDS
# At line 211 ENDATA
# Problem MODEL has 10 rows, 61 columns and 61 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 8 (-2) rows, 54 (-7) columns and 54 (-7) elements
# 0  Obj 10.374064 Primal inf 19.999992 (8)
# 8  Obj 100.23738
# Optimal - objective value 100.23738
# After Postsolve, objective 100.23738, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective 100.2373797 - 8 iterations time 0.002, Presolve 0.00
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/reol/miniconda3/envs/tensorflow/lib/python3.9/site-packages/pulp/apis/../solverdir/cbc/osx/64/cbc /var/folders/zy/j2jkps316bzfk9v5fvqrr8rm0000gn/T/dc3f318de95a41ebbde1d000d336f1b4-pulp.mps timeMode elapsed branch printingOptions all solution /var/folders/zy/j2jkps316bzfk9v5fvqrr8rm0000gn/T/dc3f318de95a41ebbde1d000d336f1b4-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 15 COLUMNS
# At line 202 RHS
# At line 213 BOUNDS
# At line 307 ENDATA
# Problem MODEL has 10 rows, 93 columns and 93 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 7 (-3) rows, 68 (-25) columns and 68 (-25) elements
# 0  Obj 13.487914 Primal inf 15.999993 (7)
# 7  Obj 79.249201
# Optimal - objective value 79.249201
# After Postsolve, objective 79.249201, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective 79.24920147 - 7 iterations time 0.002, Presolve 0.00
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/reol/miniconda3/envs/tensorflow/lib/python3.9/site-packages/pulp/apis/../solverdir/cbc/osx/64/cbc /var/folders/zy/j2jkps316bzfk9v5fvqrr8rm0000gn/T/9422d151cdb24472afaddada6f431f2d-pulp.mps timeMode elapsed branch printingOptions all solution /var/folders/zy/j2jkps316bzfk9v5fvqrr8rm0000gn/T/9422d151cdb24472afaddada6f431f2d-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 15 COLUMNS
# At line 166 RHS
# At line 177 BOUNDS
# At line 253 ENDATA
# Problem MODEL has 10 rows, 75 columns and 75 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 9 (-1) rows, 71 (-4) columns and 71 (-4) elements
# 0  Obj 5.098374 Primal inf 20.999991 (9)
# 9  Obj 96.695826
# Optimal - objective value 96.695826
# After Postsolve, objective 96.695826, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective 96.69582588 - 9 iterations time 0.002, Presolve 0.00
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/reol/miniconda3/envs/tensorflow/lib/python3.9/site-packages/pulp/apis/../solverdir/cbc/osx/64/cbc /var/folders/zy/j2jkps316bzfk9v5fvqrr8rm0000gn/T/53e2766c52974bc485df2390fa71c6fa-pulp.mps timeMode elapsed branch printingOptions all solution /var/folders/zy/j2jkps316bzfk9v5fvqrr8rm0000gn/T/53e2766c52974bc485df2390fa71c6fa-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 15 COLUMNS
# At line 160 RHS
# At line 171 BOUNDS
# At line 244 ENDATA
# Problem MODEL has 10 rows, 72 columns and 72 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 7 (-3) rows, 59 (-13) columns and 59 (-13) elements
# 0  Obj 14.30201 Primal inf 16.999993 (7)
# 7  Obj 91.732648
# Optimal - objective value 91.732648
# After Postsolve, objective 91.732648, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective 91.73264817 - 7 iterations time 0.002, Presolve 0.00
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/reol/miniconda3/envs/tensorflow/lib/python3.9/site-packages/pulp/apis/../solverdir/cbc/osx/64/cbc /var/folders/zy/j2jkps316bzfk9v5fvqrr8rm0000gn/T/625cb0567e594d708a13d16b691de2b5-pulp.mps timeMode elapsed branch printingOptions all solution /var/folders/zy/j2jkps316bzfk9v5fvqrr8rm0000gn/T/625cb0567e594d708a13d16b691de2b5-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 15 COLUMNS
# At line 210 RHS
# At line 221 BOUNDS
# At line 319 ENDATA
# Problem MODEL has 10 rows, 97 columns and 97 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 5 (-5) rows, 46 (-51) columns and 46 (-51) elements
# 0  Obj 20.677133 Primal inf 12.999995 (5)
# 5  Obj 80.649398
# Optimal - objective value 80.649398
# After Postsolve, objective 80.649398, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective 80.64939763 - 5 iterations time 0.002, Presolve 0.00
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/reol/miniconda3/envs/tensorflow/lib/python3.9/site-packages/pulp/apis/../solverdir/cbc/osx/64/cbc /var/folders/zy/j2jkps316bzfk9v5fvqrr8rm0000gn/T/025acb0346494f59871dc1b79a01040e-pulp.mps timeMode elapsed branch printingOptions all solution /var/folders/zy/j2jkps316bzfk9v5fvqrr8rm0000gn/T/025acb0346494f59871dc1b79a01040e-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 15 COLUMNS
# At line 138 RHS
# At line 149 BOUNDS
# At line 211 ENDATA
# Problem MODEL has 10 rows, 61 columns and 61 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 8 (-2) rows, 54 (-7) columns and 54 (-7) elements
# 0  Obj 10.603356 Primal inf 19.999992 (8)
# 8  Obj 101.17095
# Optimal - objective value 101.17095
# After Postsolve, objective 101.17095, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective 101.1709532 - 8 iterations time 0.002, Presolve 0.00
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/reol/miniconda3/envs/tensorflow/lib/python3.9/site-packages/pulp/apis/../solverdir/cbc/osx/64/cbc /var/folders/zy/j2jkps316bzfk9v5fvqrr8rm0000gn/T/be91d369420747e4a6a31186f7580f4c-pulp.mps timeMode elapsed branch printingOptions all solution /var/folders/zy/j2jkps316bzfk9v5fvqrr8rm0000gn/T/be91d369420747e4a6a31186f7580f4c-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 15 COLUMNS
# At line 202 RHS
# At line 213 BOUNDS
# At line 307 ENDATA
# Problem MODEL has 10 rows, 93 columns and 93 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 7 (-3) rows, 68 (-25) columns and 68 (-25) elements
# 0  Obj 13.774491 Primal inf 15.999993 (7)
# 7  Obj 79.187221
# Optimal - objective value 79.187221
# After Postsolve, objective 79.187221, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective 79.1872213 - 7 iterations time 0.002, Presolve 0.00
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/reol/miniconda3/envs/tensorflow/lib/python3.9/site-packages/pulp/apis/../solverdir/cbc/osx/64/cbc /var/folders/zy/j2jkps316bzfk9v5fvqrr8rm0000gn/T/eb2e5710c3334cc2be2519cb53175f6e-pulp.mps timeMode elapsed branch printingOptions all solution /var/folders/zy/j2jkps316bzfk9v5fvqrr8rm0000gn/T/eb2e5710c3334cc2be2519cb53175f6e-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 15 COLUMNS
# At line 166 RHS
# At line 177 BOUNDS
# At line 253 ENDATA
# Problem MODEL has 10 rows, 75 columns and 75 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 9 (-1) rows, 71 (-4) columns and 71 (-4) elements
# 0  Obj 5.2927378 Primal inf 20.999991 (9)
# 9  Obj 96.688366
# Optimal - objective value 96.688366
# After Postsolve, objective 96.688366, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective 96.68836617 - 9 iterations time 0.002, Presolve 0.00
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/reol/miniconda3/envs/tensorflow/lib/python3.9/site-packages/pulp/apis/../solverdir/cbc/osx/64/cbc /var/folders/zy/j2jkps316bzfk9v5fvqrr8rm0000gn/T/a61325d053b04ae49e828004d0954e15-pulp.mps timeMode elapsed branch printingOptions all solution /var/folders/zy/j2jkps316bzfk9v5fvqrr8rm0000gn/T/a61325d053b04ae49e828004d0954e15-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 15 COLUMNS
# At line 160 RHS
# At line 171 BOUNDS
# At line 244 ENDATA
# Problem MODEL has 10 rows, 72 columns and 72 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 7 (-3) rows, 59 (-13) columns and 59 (-13) elements
# 0  Obj 14.033383 Primal inf 16.999993 (7)
# 7  Obj 91.429687
# Optimal - objective value 91.429687
# After Postsolve, objective 91.429687, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective 91.42968719 - 7 iterations time 0.002, Presolve 0.00
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/reol/miniconda3/envs/tensorflow/lib/python3.9/site-packages/pulp/apis/../solverdir/cbc/osx/64/cbc /var/folders/zy/j2jkps316bzfk9v5fvqrr8rm0000gn/T/4fa3f566f35f4097a4129641ac0938b6-pulp.mps timeMode elapsed branch printingOptions all solution /var/folders/zy/j2jkps316bzfk9v5fvqrr8rm0000gn/T/4fa3f566f35f4097a4129641ac0938b6-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 15 COLUMNS
# At line 210 RHS
# At line 221 BOUNDS
# At line 319 ENDATA
# Problem MODEL has 10 rows, 97 columns and 97 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 5 (-5) rows, 46 (-51) columns and 46 (-51) elements
# 0  Obj 20.548302 Primal inf 12.999995 (5)
# 5  Obj 80.095277
# Optimal - objective value 80.095277
# After Postsolve, objective 80.095277, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective 80.09527744 - 5 iterations time 0.002, Presolve 0.00
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/reol/miniconda3/envs/tensorflow/lib/python3.9/site-packages/pulp/apis/../solverdir/cbc/osx/64/cbc /var/folders/zy/j2jkps316bzfk9v5fvqrr8rm0000gn/T/a755fa3403684b8f93e38f0e86a61d29-pulp.mps timeMode elapsed branch printingOptions all solution /var/folders/zy/j2jkps316bzfk9v5fvqrr8rm0000gn/T/a755fa3403684b8f93e38f0e86a61d29-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 15 COLUMNS
# At line 138 RHS
# At line 149 BOUNDS
# At line 211 ENDATA
# Problem MODEL has 10 rows, 61 columns and 61 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 8 (-2) rows, 54 (-7) columns and 54 (-7) elements
# 0  Obj 10.042889 Primal inf 19.999992 (8)
# 8  Obj 101.3347
# Optimal - objective value 101.3347
# After Postsolve, objective 101.3347, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective 101.3346956 - 8 iterations time 0.002, Presolve 0.00
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/reol/miniconda3/envs/tensorflow/lib/python3.9/site-packages/pulp/apis/../solverdir/cbc/osx/64/cbc /var/folders/zy/j2jkps316bzfk9v5fvqrr8rm0000gn/T/d6e65de33dbe4b0cb0a35754abb60796-pulp.mps timeMode elapsed branch printingOptions all solution /var/folders/zy/j2jkps316bzfk9v5fvqrr8rm0000gn/T/d6e65de33dbe4b0cb0a35754abb60796-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 15 COLUMNS
# At line 202 RHS
# At line 213 BOUNDS
# At line 307 ENDATA
# Problem MODEL has 10 rows, 93 columns and 93 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 7 (-3) rows, 68 (-25) columns and 68 (-25) elements
# 0  Obj 13.611971 Primal inf 15.999993 (7)
# 7  Obj 78.606735
# Optimal - objective value 78.606735
# After Postsolve, objective 78.606735, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective 78.60673452 - 7 iterations time 0.002, Presolve 0.00
# Option for printingOptions changed from normal to all
# ...
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/reol/miniconda3/envs/tensorflow/lib/python3.9/site-packages/pulp/apis/../solverdir/cbc/osx/64/cbc /var/folders/zy/j2jkps316bzfk9v5fvqrr8rm0000gn/T/7323ea60e4344f6980f9671ca19b217f-pulp.mps timeMode elapsed branch printingOptions all solution /var/folders/zy/j2jkps316bzfk9v5fvqrr8rm0000gn/T/7323ea60e4344f6980f9671ca19b217f-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 15 COLUMNS
# At line 202 RHS
# At line 213 BOUNDS
# At line 307 ENDATA
# Problem MODEL has 10 rows, 93 columns and 93 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 7 (-3) rows, 68 (-25) columns and 68 (-25) elements
# 0  Obj 13.491376 Primal inf 15.999993 (7)
# 7  Obj 80.073322
# Optimal - objective value 80.073322
# After Postsolve, objective 80.073322, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective 80.07332152 - 7 iterations time 0.002, Presolve 0.00
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/reol/miniconda3/envs/tensorflow/lib/python3.9/site-packages/pulp/apis/../solverdir/cbc/osx/64/cbc /var/folders/zy/j2jkps316bzfk9v5fvqrr8rm0000gn/T/b73980dd813242d8bae871ec06943b1c-pulp.mps timeMode elapsed branch printingOptions all solution /var/folders/zy/j2jkps316bzfk9v5fvqrr8rm0000gn/T/b73980dd813242d8bae871ec06943b1c-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 15 COLUMNS
# At line 166 RHS
# At line 177 BOUNDS
# At line 253 ENDATA
# Problem MODEL has 10 rows, 75 columns and 75 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 9 (-1) rows, 71 (-4) columns and 71 (-4) elements
# 0  Obj 5.2759842 Primal inf 20.999991 (9)
# 9  Obj 97.076696
# Optimal - objective value 97.076696
# After Postsolve, objective 97.076696, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective 97.07669635 - 9 iterations time 0.002, Presolve 0.00
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/reol/miniconda3/envs/tensorflow/lib/python3.9/site-packages/pulp/apis/../solverdir/cbc/osx/64/cbc /var/folders/zy/j2jkps316bzfk9v5fvqrr8rm0000gn/T/249d39867c1648699b631546f5ba3cc9-pulp.mps timeMode elapsed branch printingOptions all solution /var/folders/zy/j2jkps316bzfk9v5fvqrr8rm0000gn/T/249d39867c1648699b631546f5ba3cc9-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 15 COLUMNS
# At line 160 RHS
# At line 171 BOUNDS
# At line 244 ENDATA
# Problem MODEL has 10 rows, 72 columns and 72 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 7 (-3) rows, 59 (-13) columns and 59 (-13) elements
# 0  Obj 14.624592 Primal inf 16.999993 (7)
# 7  Obj 92.250704
# Optimal - objective value 92.250704
# After Postsolve, objective 92.250704, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective 92.25070408 - 7 iterations time 0.002, Presolve 0.00
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/reol/miniconda3/envs/tensorflow/lib/python3.9/site-packages/pulp/apis/../solverdir/cbc/osx/64/cbc /var/folders/zy/j2jkps316bzfk9v5fvqrr8rm0000gn/T/cc76bfb4cab94bada6f33be98ee5ac29-pulp.mps timeMode elapsed branch printingOptions all solution /var/folders/zy/j2jkps316bzfk9v5fvqrr8rm0000gn/T/cc76bfb4cab94bada6f33be98ee5ac29-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 15 COLUMNS
# At line 210 RHS
# At line 221 BOUNDS
# At line 319 ENDATA
# Problem MODEL has 10 rows, 97 columns and 97 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 5 (-5) rows, 46 (-51) columns and 46 (-51) elements
# 0  Obj 19.62923 Primal inf 12.999995 (5)
# 5  Obj 79.36043
# Optimal - objective value 79.36043
# After Postsolve, objective 79.36043, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective 79.36042982 - 5 iterations time 0.002, Presolve 0.00
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/reol/miniconda3/envs/tensorflow/lib/python3.9/site-packages/pulp/apis/../solverdir/cbc/osx/64/cbc /var/folders/zy/j2jkps316bzfk9v5fvqrr8rm0000gn/T/1814ad9e2b5d48049eb8f44358ba9687-pulp.mps timeMode elapsed branch printingOptions all solution /var/folders/zy/j2jkps316bzfk9v5fvqrr8rm0000gn/T/1814ad9e2b5d48049eb8f44358ba9687-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 15 COLUMNS
# At line 138 RHS
# At line 149 BOUNDS
# At line 211 ENDATA
# Problem MODEL has 10 rows, 61 columns and 61 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 8 (-2) rows, 54 (-7) columns and 54 (-7) elements
# 0  Obj 9.7689626 Primal inf 19.999992 (8)
# 8  Obj 101.12999
# Optimal - objective value 101.12999
# After Postsolve, objective 101.12999, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective 101.1299924 - 8 iterations time 0.002, Presolve 0.00
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/reol/miniconda3/envs/tensorflow/lib/python3.9/site-packages/pulp/apis/../solverdir/cbc/osx/64/cbc /var/folders/zy/j2jkps316bzfk9v5fvqrr8rm0000gn/T/e7a1f2153ae9485f96def6ebc45bf4c5-pulp.mps timeMode elapsed branch printingOptions all solution /var/folders/zy/j2jkps316bzfk9v5fvqrr8rm0000gn/T/e7a1f2153ae9485f96def6ebc45bf4c5-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 15 COLUMNS
# At line 202 RHS
# At line 213 BOUNDS
# At line 307 ENDATA
# Problem MODEL has 10 rows, 93 columns and 93 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 7 (-3) rows, 68 (-25) columns and 68 (-25) elements
# 0  Obj 13.966891 Primal inf 15.999993 (7)
# 7  Obj 80.347136
# Optimal - objective value 80.347136
# After Postsolve, objective 80.347136, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective 80.34713615 - 7 iterations time 0.002, Presolve 0.00
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/reol/miniconda3/envs/tensorflow/lib/python3.9/site-packages/pulp/apis/../solverdir/cbc/osx/64/cbc /var/folders/zy/j2jkps316bzfk9v5fvqrr8rm0000gn/T/e00339605c6f44a1bbad2fc66db12c68-pulp.mps timeMode elapsed branch printingOptions all solution /var/folders/zy/j2jkps316bzfk9v5fvqrr8rm0000gn/T/e00339605c6f44a1bbad2fc66db12c68-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 15 COLUMNS
# At line 166 RHS
# At line 177 BOUNDS
# At line 253 ENDATA
# Problem MODEL has 10 rows, 75 columns and 75 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 9 (-1) rows, 71 (-4) columns and 71 (-4) elements
# 0  Obj 4.8844813 Primal inf 20.999991 (9)
# 9  Obj 95.834585
# Optimal - objective value 95.834585
# After Postsolve, objective 95.834585, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective 95.83458465 - 9 iterations time 0.002, Presolve 0.00
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/reol/miniconda3/envs/tensorflow/lib/python3.9/site-packages/pulp/apis/../solverdir/cbc/osx/64/cbc /var/folders/zy/j2jkps316bzfk9v5fvqrr8rm0000gn/T/4a7aaec6b03c474b9df66c1b42408ed2-pulp.mps timeMode elapsed branch printingOptions all solution /var/folders/zy/j2jkps316bzfk9v5fvqrr8rm0000gn/T/4a7aaec6b03c474b9df66c1b42408ed2-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 15 COLUMNS
# At line 160 RHS
# At line 171 BOUNDS
# At line 244 ENDATA
# Problem MODEL has 10 rows, 72 columns and 72 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 7 (-3) rows, 59 (-13) columns and 59 (-13) elements
# 0  Obj 14.041073 Primal inf 16.999993 (7)
# 7  Obj 91.859085
# Optimal - objective value 91.859085
# After Postsolve, objective 91.859085, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective 91.85908465 - 7 iterations time 0.002, Presolve 0.00
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/reol/miniconda3/envs/tensorflow/lib/python3.9/site-packages/pulp/apis/../solverdir/cbc/osx/64/cbc /var/folders/zy/j2jkps316bzfk9v5fvqrr8rm0000gn/T/e2d6b83dfabe4677bb59c2ab0b0feaf4-pulp.mps timeMode elapsed branch printingOptions all solution /var/folders/zy/j2jkps316bzfk9v5fvqrr8rm0000gn/T/e2d6b83dfabe4677bb59c2ab0b0feaf4-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 15 COLUMNS
# At line 210 RHS
# At line 221 BOUNDS
# At line 319 ENDATA
# Problem MODEL has 10 rows, 97 columns and 97 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 5 (-5) rows, 46 (-51) columns and 46 (-51) elements
# 0  Obj 20.010114 Primal inf 12.999995 (5)
# 5  Obj 79.890176
# Optimal - objective value 79.890176
# After Postsolve, objective 79.890176, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective 79.89017595 - 5 iterations time 0.002, Presolve 0.00
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/reol/miniconda3/envs/tensorflow/lib/python3.9/site-packages/pulp/apis/../solverdir/cbc/osx/64/cbc /var/folders/zy/j2jkps316bzfk9v5fvqrr8rm0000gn/T/41c9956c3b6f4ffe834b01afaab6b3e3-pulp.mps timeMode elapsed branch printingOptions all solution /var/folders/zy/j2jkps316bzfk9v5fvqrr8rm0000gn/T/41c9956c3b6f4ffe834b01afaab6b3e3-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 15 COLUMNS
# At line 138 RHS
# At line 149 BOUNDS
# At line 211 ENDATA
# Problem MODEL has 10 rows, 61 columns and 61 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 8 (-2) rows, 54 (-7) columns and 54 (-7) elements
# 0  Obj 9.693151 Primal inf 19.999992 (8)
# 8  Obj 99.811794
# Optimal - objective value 99.811794
# After Postsolve, objective 99.811794, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective 99.81179358 - 8 iterations time 0.002, Presolve 0.00
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/reol/miniconda3/envs/tensorflow/lib/python3.9/site-packages/pulp/apis/../solverdir/cbc/osx/64/cbc /var/folders/zy/j2jkps316bzfk9v5fvqrr8rm0000gn/T/1e1c1191292b425e9471f95229e4faac-pulp.mps timeMode elapsed branch printingOptions all solution /var/folders/zy/j2jkps316bzfk9v5fvqrr8rm0000gn/T/1e1c1191292b425e9471f95229e4faac-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 15 COLUMNS
# At line 202 RHS
# At line 213 BOUNDS
# At line 307 ENDATA
# Problem MODEL has 10 rows, 93 columns and 93 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 7 (-3) rows, 68 (-25) columns and 68 (-25) elements
# 0  Obj 13.350541 Primal inf 15.999993 (7)
# 7  Obj 79.697139
# Optimal - objective value 79.697139
# After Postsolve, objective 79.697139, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective 79.69713895 - 7 iterations time 0.002, Presolve 0.00
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/reol/miniconda3/envs/tensorflow/lib/python3.9/site-packages/pulp/apis/../solverdir/cbc/osx/64/cbc /var/folders/zy/j2jkps316bzfk9v5fvqrr8rm0000gn/T/5322b7adb90a4d99bd414681ae7f7a5c-pulp.mps timeMode elapsed branch printingOptions all solution /var/folders/zy/j2jkps316bzfk9v5fvqrr8rm0000gn/T/5322b7adb90a4d99bd414681ae7f7a5c-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 15 COLUMNS
# At line 166 RHS
# At line 177 BOUNDS
# At line 253 ENDATA
# Problem MODEL has 10 rows, 75 columns and 75 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 9 (-1) rows, 71 (-4) columns and 71 (-4) elements
# 0  Obj 4.8465755 Primal inf 20.999991 (9)
# 9  Obj 96.399361
# Optimal - objective value 96.399361
# After Postsolve, objective 96.399361, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective 96.39936101 - 9 iterations time 0.002, Presolve 0.00
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/reol/miniconda3/envs/tensorflow/lib/python3.9/site-packages/pulp/apis/../solverdir/cbc/osx/64/cbc /var/folders/zy/j2jkps316bzfk9v5fvqrr8rm0000gn/T/d05b2ccc3c5246ed8b02e4bf7b7f3e64-pulp.mps timeMode elapsed branch printingOptions all solution /var/folders/zy/j2jkps316bzfk9v5fvqrr8rm0000gn/T/d05b2ccc3c5246ed8b02e4bf7b7f3e64-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 15 COLUMNS
# At line 160 RHS
# At line 171 BOUNDS
# At line 244 ENDATA
# Problem MODEL has 10 rows, 72 columns and 72 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 7 (-3) rows, 59 (-13) columns and 59 (-13) elements
# 0  Obj 14.887162 Primal inf 16.999993 (7)
# 7  Obj 92.217299
# Optimal - objective value 92.217299
# After Postsolve, objective 92.217299, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective 92.21729914 - 7 iterations time 0.002, Presolve 0.00
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/reol/miniconda3/envs/tensorflow/lib/python3.9/site-packages/pulp/apis/../solverdir/cbc/osx/64/cbc /var/folders/zy/j2jkps316bzfk9v5fvqrr8rm0000gn/T/e76358abe0fc489fbb062a850b2aed8e-pulp.mps timeMode elapsed branch printingOptions all solution /var/folders/zy/j2jkps316bzfk9v5fvqrr8rm0000gn/T/e76358abe0fc489fbb062a850b2aed8e-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 15 COLUMNS
# At line 210 RHS
# At line 221 BOUNDS
# At line 319 ENDATA
# Problem MODEL has 10 rows, 97 columns and 97 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 5 (-5) rows, 46 (-51) columns and 46 (-51) elements
# 0  Obj 20.646588 Primal inf 12.999995 (5)
# 5  Obj 80.93915
# Optimal - objective value 80.93915
# After Postsolve, objective 80.93915, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective 80.93915007 - 5 iterations time 0.002, Presolve 0.00
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
